# %% [markdown]
# #section 1

# %%
print("hello") #this is my first line of python code
# Out:
# hello

# %% [markdown]
# ##sub section 1
#
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# #**title**
# > hi
# `hellooo`

# %% [markdown]
# **title**
#
# * faheema

# %% [markdown]
# i am faheema

# %%
print("i am here")
# Out:
# i am here
