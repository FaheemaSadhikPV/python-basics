# %% [markdown]
# ##Variables in python
# * a variable is a name that refers to a value stored in memory.
# * you can assign values using the '=' operator. python is dynamically typed.
# rules for naming variables:
# 1.must start with a letter or underscore _
# 2.cannot start with a number
# 3.can contain letters, digits, and underscores
# 4.case-sensitive (`Name`=!`name`)
# 5.should not use python keywords (`if`, `for`,`class`,etc)

# %%
name , age , gender, location , qualification , score = "faheema", 22 , "female" , "parappanangadi" , "UG" , 7.34
name
# Out:
# 'faheema'

# %% [markdown]
# ## variables assignment in python

# %%
x = 10           #assigns the integer 10 to variable x
name = "faheema" #assigns string 'faheema' to variable name
is_valid = False #assigns boolean to variable is_valid
is_valid
# Out:
# False

# %%
#show all variable types
print(type(x),type(name),type(is_valid))
# Out:
# <class 'int'> <class 'str'> <class 'bool'>

# %%
name = 'emin'
name
print(name)
print("name")
print("my name is",name)
print("my name is",name,"and everyone call me",name)
# Out:
# emin
# name
# my name is emin
# my name is emin and everyone call me emin
